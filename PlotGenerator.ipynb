# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
dfDA = pd.read_csv("./Results/Caltech256logDataAugmentation.csv")
dfDA.head()
# Out:
#    epoch  accuracy      loss  val_accuracy  val_loss
# 0      0  0.113906  4.786638      0.128879  4.910822
# 1      1  0.164876  4.214121      0.162365  4.568058
# 2      2  0.201307  3.911089      0.223293  3.936714
# 3      3  0.229038  3.700831      0.210715  4.053270
# 4      4  0.253339  3.526994      0.279157  3.513827

# %%
ax = plt.gca()
dfDA.plot(kind='line',x='epoch',y='accuracy',color='#0a674f', ax=ax, title = 'Training vs validation accuracy of CNN using Data Augmentation' )
dfDA.plot(kind='line',x='epoch',y='val_accuracy', color='red', ax=ax)
plt.savefig('./Plots/DAAccuracy.png', dpi = 400)
plt.show()

# %%
ax = plt.gca()
dfDA.plot(kind='line',x='epoch',y='loss', color='#adf802', ax=ax, title = 'Training loss vs Validation loss of CNN using Data Augmentation')
dfDA.plot(kind='line',x='epoch',y='val_loss', color='#FFA500', ax=ax)
plt.savefig('./Plots/DALoss.png', dpi = 400)
plt.show()

# %%
dfPlainCNN = pd.read_csv("./Results/Caltech256logCNN.csv")

# %%
dfPlainCNN.head()
# Out:
#    epoch  accuracy      loss  val_accuracy  val_loss
# 0      0  0.184358  4.248429      0.224763  3.926489
# 1      1  0.356872  3.014762      0.302842  3.366013
# 2      2  0.503410  2.196198      0.260046  4.053831
# 3      3  0.691485  1.311264      0.365567  3.349469
# 4      4  0.902348  0.474028      0.360176  3.587973

# %%
ax = plt.gca()
dfPlainCNN.plot(kind='line',x='epoch',y='accuracy',color='#0a674f', ax=ax, title = 'Training vs validation accuracy of CNN\nwithout using any enhancement techniques' )
dfPlainCNN.plot(kind='line',x='epoch',y='val_accuracy', color='red', ax=ax)
plt.savefig('./Plots/PlainCNNAccuracy.png', dpi = 400)
plt.show()

# %%
ax = plt.gca()
dfPlainCNN.plot(kind='line',x='epoch',y='loss', color='#adf802', ax=ax, title = 'Training loss vs Validation loss of CNN\nwithout any enhancement Techniques ')
dfPlainCNN.plot(kind='line',x='epoch',y='val_loss', color='#FFA500', ax=ax)
plt.savefig('./Plots/PlainCNNLoss.png', dpi = 400)
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
dfANN = pd.read_csv("./Results/Caltech256ANN.csv")
dfANN.head()
# Out:
#    epoch  accuracy      loss  val_accuracy  val_loss
# 0      0  0.027364  6.024485      0.026135  5.473758
# 1      1  0.025322  5.484792      0.027279  5.663809
# 2      2  0.025158  5.491051      0.026135  5.469368
# 3      3  0.025567  5.487404      0.026789  5.479222
# 4      4  0.026751  5.509414      0.002777  6.875255

# %%
ax = plt.gca()
dfANN.plot(kind='line',x='epoch',y='accuracy',color='#0a674f', ax=ax, title = 'Training vs validation accuracy of ANN' )
dfANN.plot(kind='line',x='epoch',y='val_accuracy', color='red', ax=ax)
plt.savefig('./Plots/ANNAccuracy.png', dpi = 400)
plt.show()

# %%
ax = plt.gca()
dfANN.plot(kind='line',x='epoch',y='loss', color='#adf802', ax=ax, title = 'Training loss vs Validation loss of ANN')
dfANN.plot(kind='line',x='epoch',y='val_loss', color='#FFA500', ax=ax)
plt.savefig('./Plots/ANNLoss.png', dpi = 400)
plt.show()

# %%
dfTL = pd.read_csv("./Results/Caltech256TL.csv")
dfTL.head()
# Out:
#    epoch  accuracy      loss  val_accuracy  val_loss
# 0      0  0.188319  4.075764      0.336165  2.994750
# 1      1  0.325342  3.059761      0.410323  2.632656
# 2      2  0.374025  2.774089      0.426658  2.547714
# 3      3  0.401634  2.628738      0.442339  2.465668
# 4      4  0.423239  2.520862      0.473538  2.333609

# %%
ax = plt.gca()
dfTL.plot(kind='line',x='epoch',y='accuracy',color='#0a674f', ax=ax, title = 'Training vs validation accuracy of CNN\n with Transfer Learning and Data Augmentation' )
dfTL.plot(kind='line',x='epoch',y='val_accuracy', color='red', ax=ax)
plt.savefig('./Plots/TLAccuracy.png', dpi = 400)
plt.show()

# %%
ax = plt.gca()
dfTL.plot(kind='line',x='epoch',y='loss', color='#adf802', ax=ax, title = 'Training loss vs Validation loss of CNN\nwith Transfer Learning and Data Augmentation')
dfTL.plot(kind='line',x='epoch',y='val_loss', color='#FFA500', ax=ax)
plt.savefig('./Plots/TLLoss.png', dpi = 400)
plt.show()
